# %% [markdown]
# <a href="https://colab.research.google.com/github/hhharshitt/ML-Experiments/blob/main/Experiment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Experiment 1: Central Tendency & Dispersion

# %%
target = df['math score']

print(f"Mean: {target.mean():.2f}")
print(f"Median: {target.median()}")

print(f"Mode: {df['gender'].mode()[0]}")
# Out:
# Mean: 66.09
# Median: 66.0
# Mode: female

# %%
#Experiment 2: Quartiles and Percentiles

# %%
Q1 = df['reading score'].quantile(0.25)
Q2 = df['reading score'].quantile(0.50)
Q3 = df['reading score'].quantile(0.75)

print(f"25th Percentile (Q1): {Q1}")
print(f"50th Percentile (Median/Q2): {Q2}")
print(f"75th Percentile (Q3): {Q3}")
print(f"Interquartile Range (IQR): {Q3 - Q1}")
# Out:
# 25th Percentile (Q1): 59.0
# 50th Percentile (Median/Q2): 70.0
# 75th Percentile (Q3): 79.0
# Interquartile Range (IQR): 20.0

# %%
#Experiment 3: Correlation & Covariance

# %%
numeric_df = df[['math score', 'reading score', 'writing score']]

print("--- Correlation Matrix ---")
print(numeric_df.corr())

print("\n--- Covariance Matrix ---")
print(numeric_df.cov())
# Out:
# --- Correlation Matrix ---
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
#
# --- Covariance Matrix ---
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
#Experiment 4: Histograms & Boxplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['writing score'], kde=True, color='blue')
plt.title("Distribution of Writing Scores")

plt.subplot(1, 2, 2)
sns.boxplot(y=df['writing score'], color='lightgreen')
plt.title("Boxplot of Writing Scores")

plt.tight_layout()
plt.show()
